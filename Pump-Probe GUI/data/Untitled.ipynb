# %%
import numpy as np
a = np.loadtxt('_avg.txt')

# %%
a
# Out:
# array([[ 9.70000030e+01,  4.00276915e-05,  2.54354901e-07],
#        [ 9.69999970e+01, -4.00276915e-05,  4.10575559e-07],
#        [ 9.70000040e+01,  5.33702553e-05, -4.66647558e-07],
#        ...,
#        [ 9.77354030e+01,  9.81216145e+00,  7.52886478e-07],
#        [ 9.77498910e+01,  1.00054685e+01, -3.50239045e-07],
#        [ 9.77496680e+01,  1.00024931e+01, -5.88958387e-07]])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a[:,1], a[:,2], '.')
# plt.xlim(0,1)

# %%
a[:,1], a[:,2]
# Out:
# (array([-5.33702553e-05, -2.66851276e-05,  3.06878968e-04,  6.63392272e-02,
#          1.35733902e-01,  1.95361819e-01,  2.52948325e-01,  3.13643647e-01,
#          3.75406375e-01,  4.31525199e-01,  4.94288619e-01,  5.53916536e-01,
#          6.15225617e-01,  6.74559998e-01,  7.43260859e-01,  8.06224418e-01,
#          8.66999796e-01,  9.26134039e-01,  9.84534441e-01,  1.04763143e+00,
#          1.10635205e+00,  1.16838163e+00,  1.23460077e+00,  1.29717740e+00,
#          1.35903352e+00,  1.42876176e+00,  1.49341982e+00,  1.55801118e+00,
#          1.61819948e+00,  1.68349799e+00,  1.74778246e+00,  1.82946564e+00,
#          1.89064129e+00,  1.93715347e+00,  1.98718808e+00,  2.04058502e+00,
#          2.09677056e+00,  2.14847300e+00,  2.19800059e+00,  2.24928941e+00,
#          2.29967093e+00,  2.34830457e+00,  2.39955336e+00,  2.45005496e+00,
#          2.50010292e+00,  2.54935032e+00,  2.60230696e+00,  2.65809222e+00,
# ...
